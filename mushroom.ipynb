# %%
# !git clone https://github.com/tensorflow/agents.git

# !pip install tensorflow tf-agents tensorflow-datasets

cd /Users/benedict/UDC_research/UDC_MAB/agents/tf_agents/bandits/agents/examples/v2

# !python train_eval_mushroom.py --root_dir=/Users/benedict/UDC_research/UDC_MAB/mushroom - mushroom.csv

# %%
# !git clone https://github.com/tensorflow/agents.git
# Out:
# Cloning into 'agents'...
# remote: Enumerating objects: 21043, done.
# remote: Counting objects: 100% (997/997), done.
# remote: Compressing objects: 100% (674/674), done.
# remote: Total 21043 (delta 409), reused 635 (delta 322), pack-reused 20046
# Receiving objects: 100% (21043/21043), 13.02 MiB | 15.42 MiB/s, done.
# Resolving deltas: 100% (15790/15790), done.

# %%
# !pip install tensorflow tf-agents tensorflow-datasets

# %%
cd /Users/benedict/UDC_research/UDC_MAB/agents/tf_agents/bandits/agents/examples/v2
# Out:
# /Users/benedict/UDC_research/UDC_MAB/agents/tf_agents/bandits/agents/examples/v2

# %%
# !python train_eval_mushroom.py --root_dir=/Users/benedict/UDC_research/UDC_MAB/mushroom - mushroom.csv
# Out:
# 2023-09-22 10:02:46.721397: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-09-22 10:02:46.721427: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-09-22 10:02:46.721438: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-09-22 10:02:46.721883: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-22 10:02:46.722275: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# I0922 10:02:47.115766 8439226496 trainer.py:125] Did not find a pre-existing checkpoint. Starting from scratch.
# ...
